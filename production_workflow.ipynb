# %% [markdown]
# <a href="https://colab.research.google.com/github/zkc1031/BadmintonNetTouch/blob/main/production_workflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==============================================================================
# 【役割】環境設定 ＆ ライブラリインポート
# ==============================================================================
# 目的：
# Colabのセッションを開始する際に、毎回最初に実行するセル。
# Google Driveをマウントし、NumPyのバージョン競合を防ぎながら、
# 研究に必要なすべてのライブラリをインストール・インポートします。
# ==============================================================================

# === ステップ1：Google Driveのマウント ===
from google.colab import drive
drive.mount('/content/drive')

# === ステップ2：ライブラリのバージョンを固定してインストール ===
# NumPyのバージョン競合エラーを防ぐため、バージョンを厳密に指定します
# !pip install numpy==1.26.4
# !pip install mediapipe==0.10.9 ultralytics pandas opencv-python scipy pillow bleak

# === ステップ3：主要ライブラリのインポート（確認用） ===
print("\n--- ライブラリのインポートを開始します ---")

try:
    # 汎用ライブラリ
    import os
    import pandas as pd
    import numpy as np

    # AI・画像処理用
    import cv2
    import mediapipe as mp
    from mediapipe.tasks import python
    from mediapipe.tasks.python import vision

    print("✅ すべてのライブラリのインポートに成功しました。")

except ImportError as e:
    print(f"❌ エラー: ライブラリのインポートに失敗しました。")
    print(f"詳細: {e}")
